# %% [markdown]
# <a href="https://colab.research.google.com/github/ArpitSahu2/ml.BootCamp2026/blob/main/b2_session5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#first code snippet
marks=[78,63,62]
avg=sum(marks)/ len(marks)
print(avg)

# %%
#second code snipptt
def caclculate_average(marks):
  return sum(marks)/ len(marks)
marks=[78,63,62]
print(caclculate_average(marks))

# %%
def get_result_status(score):
    if score >= 27:
        return "Pass"
    return "Fail"

print(get_result_status(85))
print(get_result_status(32))

# %%
import numpy as np

arr=np.array([10,20,30,40])
print(arr)
print(arr.shape)


matrix =np.array([
    [10,20,30],
    [40,50,60]
])
print(matrix)
print(matrix.shape)

# %%
#slicing?
grid = np.array([
    [11, 12, 13, 14, 15],
    [21, 22, 23, 24, 25],
    [31, 32, 33, 34, 35],
    [41, 42, 43, 44, 45],
    [51, 52, 53, 54, 55]
])
print(grid[0,0])
print(grid[0])
print(grid[:,0])
print(grid[0:3, 0:3])
print(grid[1:4, 1:4])

# %%
marks = np.array([78, 91, 55, 72, 40, 88])

print(marks > 70)

high_scores = marks[marks > 70]
print(high_scores)

# %%
marks = np.array([78, 91, 55, 72, 40, 88])

print(marks.mean())
print(marks.min())
print(marks.max())
print(marks.sum())
